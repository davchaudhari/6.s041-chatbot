# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="meta-llama/Llama-3.2-1B")
# Out:
# model.safetensors:   3%|3         | 83.9M/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# Device set to use mps:0

# %%
pipe("The winner of the 1789 election is", max_length=50, do_sample=True, temperature=0.7)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [{'generated_text': 'The winner of the 1789 election is determined by the number of votes cast for each candidate. The candidate with the highest number of votes wins.\nThe winner of the 1789 election was John Adams.'}]
